# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = requests.get("https://www.yelp.com/biz/tesla-san-francisco?osq=Tesla+Dealership")

# %%
url.status_code
# Out:
# 200

# %%
url.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej quqnuc 1n9j64s 4ut3yi 110vchp tza3mu 1enow5j 1jp7iek 1r5qcd8 cfcjyn 8dlaw4 xlzvdl 2sacua 1sb02f4 1sie4w0 qgunke kma813 15j7fnr war30n 79elbk 1t0p8qh 1suk6u5 1evauet e0tek0 ije6j5 ralh0w wonnhn 1fygppl 1udg11w 1fkqezt 1pz4y59 ux5mu6 1m051bw 1nrzw89 1fnccdf chan6m 9hjhab inq9gi 1c2abjj 12i50in 1lr1m88 6a0jil 1oibaro 1yi23de 6icbtg 1m45yea 1p2252a hrssq9 1g8th6j wuu41 gutk1c foyide 1lx34my 144i0wq 1kq79li 1rjq8gp 16agjqd 1uk2nuw 19cdu5a 1ljw62o nyjpex p2pgf9 8h74hi 1gbck26 1g83tkj 70yie2 18yz3zi 190j3wt 8xs00z 1170h8t 1kuwv4w 4zp531 jcl426 1h0y4i5 h19vjk 1m2gifa dh50jt yyr98k 4mfze4 1jac6c2 cv1jz2 fksa8h 147xtl9 19sk4h4 dyjx0f 1p9ibgf 1ufst7j ja6w1z 15hxdct qyp8bo 1r80nfg 1xluaz5 142tcj8 1fliqpp r9996t 1um3nx cktstf 1t7f977 106vfgv 1p80smk cednmx xp8w2v 1vhakgw na3oda qi10u5 qr9z5e 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive .responsive-desktop-smal ...

# %%
soup = BeautifulSoup(url.text, "html.parser")

# %%
divs = soup.findAll(class_="comment__09f24__gu0rG css-qgunke")
print(divs)
# Out:
# [<p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Consider the Tesla Model 3. Mine is fun, which brings joy and contentment.  I look forward to each drive. <br/><br/>Over the air updates and a good autopilot system keeps the car renewable and removes some of the mind numbing heavy traffic.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">This is for our amazing experience with the service center.  They went above and beyond for us and it was the best repair experience we've ever had with any car.<br/><br/>We had a warranty repair on our Model Y that was going to take a long time to complete.  The shop was incredibly understanding and helpful about our kids and car seats and worked with us to plan ahead.  <br/><br/>When the day came they fixed a major issue for us 40% faster than expected, and they fixed a minor issue even though we didn't think the parts were in stock!  Finally, they were ultra flexible with us on pickup.  THANK YOU!</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Today I went to the San Francisco Tesla Dealer for the first time and I was impressed! Great customer service! I would like to thank Nick who helped me out today, he was so knowledgeable and was amazing at answering all my questions and explaining all about the features I didn't know about the new Model Y I ordered. He went as far as setting an appointment for me at another Tesla location that had the exact car I wanted and I got to drive it today! I was overall very satisfied with my visit and he gave me reassure that I was making the right decision of choosing a model for my needs. I am excited for my new Tesla!</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Crappy plastic piece falls off the bottom of the model y, exposing all kinds of important hardware, so often they make an aftermarket replacement for it but tesla doesn't cover it under their warranty! <br/>They charged me $250 for something that should be covered by warranty. I'll be waiting for the recall to get my money back.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Well, I had an issue with my Tesla. Took it into the service center on Thursday. They called me earlier today to tell me to come in and pick up my car and then summarily canceled the Uber voucher that I was given. <br/><br/>I'M CURRENTLY ON THE CALTRAIN TO SAVE THEM $ AND NOT USE IT ALL. THEN I WENT TO ORDER A RIDE AND IT SAID CANCELED <br/><br/>WOW. Last Tesla I own.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Do you love having your car held hostage for things that aren't your fault? If so, this location is 100% for you. My guy Kenny is king grinch. If you want a poor customer service experience where you get made to feel like you at fault for the dealer's shoddy service, this guy is your knight in shining armor.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Kevin and Bridget were amazing. I purchased a used Tesla abs picked it up in Rocklin. That experience was horrible and made me second guess my purchase. Kevin gave me a real live tutorial, showed me how everything works and answered all the questions about all the features in my model 3 long range. They redeemed my confidence in this company and am truly grateful for the time they took with me. Bridget was very apologetic and told me she would follow up on the poor experience I received in Rocklin. Please reward and acknowledge Kevin and Bridget for being the best way to build trust and confidence in the Tesla company and product. I will definitely go back to them if I have any other questions.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">I am appalled by the poor service at thi ...

# %%
reviews = []
for div in divs:
    reviews.append(div.find('span').text)

# %%
reviews[0]
# Out:
# 'Consider the Tesla Model 3. Mine is fun, which brings joy and contentment. \xa0I look forward to each drive. Over the air updates and a good autopilot system keeps the car renewable and removes some of the mind numbing heavy traffic.'

# %% [markdown]
# # Analysing the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.array(reviews), columns=["review"])

# %%
len(df['review'])
# Out:
# 10

# %%
df["word_count"] = df["review"].apply(lambda x: len(x.split()))

# %%
df['char_count']=df['review'].apply(lambda x: len(x))

# %%
def avg_word(review):
  words = review.split()
  return (sum(len(word) for word in words) / len(words))

# Calculate average words
df['avg_word'] = df['review'].apply(lambda x: avg_word(x))

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word
# 0  4.609756
# 1  4.300000
# 2  4.140496
# 3  4.719298
# 4  3.808219

# %%
# !pip3 install nltk

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 18.1 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk) (0.17.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk) (2021.11.2)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk) (8.0.3)
# Installing collected packages: nltk
# Successfully installed nltk-3.7
# [nltk_data] Downloading package stopwords to /home/wsuser/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/wsuser/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package omw-1.4 to /home/wsuser/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
# Import stopwords
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
df['stopword_count'] = df['review'].apply(lambda x: len([x for x in x.split() if x in stop_words]))

# %%
df.describe()
# Out:
#        word_count  char_count   avg_word  stopword_count
# count   10.000000   10.000000  10.000000       10.000000
# mean    78.900000  419.900000   4.291305       33.600000
# std     41.364101  218.327201   0.461689       19.132288
# min     13.000000   56.000000   3.384615        6.000000
# 25%     54.750000  312.250000   4.148282       21.750000
# 50%     66.000000  337.500000   4.277119       26.500000
# 75%    118.250000  612.500000   4.593144       52.750000
# max    134.000000  703.000000   4.981481       58.000000

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count
# 0  4.609756              14
# 1  4.300000              49
# 2  4.140496              54
# 3  4.719298              27
# 4  3.808219              21

# %%
df["stopword_rate"] = df["stopword_count"] /df["word_count"]

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count  stopword_rate
# 0  4.609756              14       0.341463
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 3  4.719298              27       0.473684
# 4  3.808219              21       0.287671

# %%
df.sort_values(by="stopword_rate")
# Out:
#                                               review  word_count  char_count  \
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 5  Do you love having your car held hostage for t...          59         309
# 7  I am appalled by the poor service at this Tesl...         134         696
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 6  Kevin and Bridget were amazing. I purchased a ...         127         703
# 8  Dear dad can you buy me a Tesla to drive at gr...          13          56
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 9  I ended up filing a complaint against them wit...          54         322
#
#    avg_word  stopword_count  stopword_rate
# 4  3.808219              21       0.287671
# 0  4.609756              14       0.341463
# 5  4.254237              24       0.406780
# 7  4.171642              58       0.432836
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 6  4.543307              57       0.448819
# 8  3.384615               6       0.461538
# 3  4.719298              27       0.473684
# 9  4.981481              26       0.481481

# %% [markdown]
# # Data Cleaning

# %%
df["lowercase"] = df["review"].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df["Punctuation"] = df["lowercase"].str.replace('[^\w\s]',"")
# Out:
# /tmp/wsuser/ipykernel_210/783971732.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Punctuation"] = df["lowercase"].str.replace('[^\w\s]',"")

# %%
df["Stopwords"] = df["Punctuation"].apply(lambda x:" ".join(word for word in x.split() if word not in stop_words))

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count  stopword_rate  \
# 0  4.609756              14       0.341463
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 3  4.719298              27       0.473684
# 4  3.808219              21       0.287671
#
#                                            lowercase  \
# 0  consider the tesla model 3. mine is fun, which...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well, i had an issue with my tesla. took it in...
#
#                                          Punctuation  \
# 0  consider the tesla model 3 mine is fun which b...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well i had an issue with my tesla took it into...
#
#                                            Stopwords
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...

# %%
pd.Series(" ".join(df['Stopwords']).split()).value_counts()[:30]
# Out:
# tesla         13
# service        8
# model          7
# car            7
# today          5
# experience     5
# us             4
# went           4
# new            4
# repair         4
# issue          3
# amazing        3
# would          3
# time           3
# kevin          3
# location       3
# bridget        3
# warranty       3
# get            3
# didnt          3
# back           3
# drive          3
# questions      3
# poor           3
# like           2
# speak          2
# features       2
# way            2
# gave           2
# app            2
# dtype: int64

# %%
other_stop_words=["us", "get", "would","go", "ap", "melissa", "kevin", "bridget", "say" ]

# %%
len(other_stop_words)
# Out:
# 9

# %%
df["Clean Review"] = df["Stopwords"].apply(lambda x: " ".join(word for word in x.split() if word not in other_stop_words))

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count  stopword_rate  \
# 0  4.609756              14       0.341463
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 3  4.719298              27       0.473684
# 4  3.808219              21       0.287671
#
#                                            lowercase  \
# 0  consider the tesla model 3. mine is fun, which...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well, i had an issue with my tesla. took it in...
#
#                                          Punctuation  \
# 0  consider the tesla model 3 mine is fun which b...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well i had an issue with my tesla took it into...
#
#                                            Stopwords  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...
#
#                                         Clean Review
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...

# %% [markdown]
# # Lemmatize Text

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: nltk>=3.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2021.11.2)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk>=3.1->textblob) (0.17.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
#Import textblob
from textblob import Word

# %%
df["lemmatized"] = df["Clean Review"].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count  stopword_rate  \
# 0  4.609756              14       0.341463
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 3  4.719298              27       0.473684
# 4  3.808219              21       0.287671
#
#                                            lowercase  \
# 0  consider the tesla model 3. mine is fun, which...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well, i had an issue with my tesla. took it in...
#
#                                          Punctuation  \
# 0  consider the tesla model 3 mine is fun which b...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well i had an issue with my tesla took it into...
#
#                                            Stopwords  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...
#
#                                         Clean Review  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...
#
#                                           lemmatized
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece fall bottom model exposin...
# 4  well issue tesla took service center thursday ...

# %% [markdown]
# # Sentiment Analysis

# %%
from textblob import TextBlob

# %%
df["polarity"] = df["lemmatized"].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df["subjectivity"] = df["lemmatized"].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
#
#    avg_word  stopword_count  stopword_rate  \
# 0  4.609756              14       0.341463
# 1  4.300000              49       0.445455
# 2  4.140496              54       0.446281
# 3  4.719298              27       0.473684
# 4  3.808219              21       0.287671
#
#                                            lowercase  \
# 0  consider the tesla model 3. mine is fun, which...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well, i had an issue with my tesla. took it in...
#
#                                          Punctuation  \
# 0  consider the tesla model 3 mine is fun which b...
# 1  this is for our amazing experience with the se...
# 2  today i went to the san francisco tesla dealer...
# 3  crappy plastic piece falls off the bottom of t...
# 4  well i had an issue with my tesla took it into...
#
#                                            Stopwords  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...
#
#                                         Clean Review  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  amazing experience service center went beyond ...
# 2  today went san francisco tesla dealer first ti...
# 3  crappy plastic piece falls bottom model exposi...
# 4  well issue tesla took service center thursday ...
#
#                                           lemmatized  polarity  subjectivity
# 0  consider tesla model 3 mine fun brings joy con...  0.400000      0.375000
# 1  amazing experience service center went beyond ...  0.213542      0.458333
# 2  today went san francisco tesla dealer first ti...  0.369453      0.619012
# 3  crappy plastic piece fall bottom model exposin...  0.125000      0.725000
# 4  well issue tesla took service center thursday ...  0.000000      0.413333

# %%
df.drop(["lowercase", "Punctuation", "Stopwords","Clean Review", "lemmatized"], axis=1, inplace=True)

# %%
df.sort_values(by="polarity")
# Out:
#                                               review  word_count  char_count  \
# 5  Do you love having your car held hostage for t...          59         309
# 9  I ended up filing a complaint against them wit...          54         322
# 7  I am appalled by the poor service at this Tesl...         134         696
# 4  Well, I had an issue with my Tesla. Took it in...          73         350
# 8  Dear dad can you buy me a Tesla to drive at gr...          13          56
# 6  Kevin and Bridget were amazing. I purchased a ...         127         703
# 3  Crappy plastic piece falls off the bottom of t...          57         325
# 1  This is for our amazing experience with the se...         110         587
# 2  Today I went to the San Francisco Tesla Dealer...         121         621
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
#
#    avg_word  stopword_count  stopword_rate  polarity  subjectivity
# 5  4.254237              24       0.406780 -0.066667      0.566667
# 9  4.981481              26       0.481481 -0.054545      0.251515
# 7  4.171642              58       0.432836 -0.039773      0.462085
# 4  3.808219              21       0.287671  0.000000      0.413333
# 8  3.384615               6       0.461538  0.000000      0.000000
# 6  4.543307              57       0.448819  0.044318      0.493750
# 3  4.719298              27       0.473684  0.125000      0.725000
# 1  4.300000              49       0.445455  0.213542      0.458333
# 2  4.140496              54       0.446281  0.369453      0.619012
# 0  4.609756              14       0.341463  0.400000      0.375000
